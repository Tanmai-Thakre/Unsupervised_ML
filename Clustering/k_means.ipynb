# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module="sklearn")

# %%
import seaborn as sns
from sklearn.datasets import make_blobs

# %%
X , y = make_blobs(
    n_samples=1000,
    n_features=2,
    random_state=42,
    centers=4
)

# %%
sns.scatterplot(x=X[:,0] , y=X[:,1])
# Out:
# <Axes: >

# %%
# K-means clustering
from sklearn.cluster import KMeans

# %%
k=4

kmeans = KMeans(
    n_clusters=k,
    random_state=42    
)

kmeans
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
labels = kmeans.fit_predict(X)
# label = cluster name

# %%
sns.scatterplot(x=X[:,0] , y=X[:,1] , c=labels)
# Out:
# <Axes: >

# %% [markdown]
# ## Choose the K value

# %%
# Elbow method 
wcss = []
for k in range(1,21):
    kmeans = KMeans(n_clusters=k)
    kmeans.fit_predict(X)
    wcss.append(kmeans.inertia_)

# %%
sns.lineplot(x=range(1,21) , y=wcss , marker='o')
# Out:
# <Axes: >

# %%
# !pip install kneed
# Out:
# Collecting kneed
#   Downloading kneed-0.8.5-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\asus\anaconda3\lib\site-packages (from kneed) (2.1.3)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\asus\anaconda3\lib\site-packages (from kneed) (1.15.3)
# Downloading kneed-0.8.5-py3-none-any.whl (10 kB)
# Installing collected packages: kneed
# Successfully installed kneed-0.8.5

# %%
from kneed import KneeLocator

# %%
knee = KneeLocator(range(1,21) ,wcss ,curve="convex" , direction="decreasing")

# %%
print(knee.elbow)
# Out:
# 4
